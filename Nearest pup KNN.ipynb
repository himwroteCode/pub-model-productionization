# %%
import mlflow

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('open_pubs.csv', header=None)

# %%
df
# Out:
#             0                                         1
# 0          22                                Anchor Inn  \
# 1          36                        Ark Bar Restaurant
# 2          74                                 Black Boy
# 3          75                               Black Horse
# 4          76                                Black Lion
# ...       ...                                       ...
# 51326  597119  Wrexham & District War Memorial Club Ltd
# 51327  597127                 Wrexham Lager Social Club
# 51328  597130         Wrexham Rail Sports & Social Club
# 51329  597131                        Wrexham Rugby Club
# 51330  597137                                     Y Tai
#
#                                                        2         3       4
# 0            Upper Street, Stratford St Mary, COLCHESTER   CO7 6LW  604749  \
# 1      Ark Bar And Restaurant, Cattawade Street, Bran...  CO11 1RH  610194
# ...

# %% [markdown]
# ### Providing headings to the column

# %%
df.columns= ["fsa_id", "name", "address", "postcode", "easting", "northing", "latitude", "longitude", "local_authority"]

# %%
df
# Out:
#        fsa_id                                      name
# 0          22                                Anchor Inn  \
# 1          36                        Ark Bar Restaurant
# 2          74                                 Black Boy
# 3          75                               Black Horse
# 4          76                                Black Lion
# ...       ...                                       ...
# 51326  597119  Wrexham & District War Memorial Club Ltd
# 51327  597127                 Wrexham Lager Social Club
# 51328  597130         Wrexham Rail Sports & Social Club
# 51329  597131                        Wrexham Rugby Club
# 51330  597137                                     Y Tai
#
#                                                  address  postcode  easting
# 0            Upper Street, Stratford St Mary, COLCHESTER   CO7 6LW   604749  \
# 1      Ark Bar And Restaurant, Cattawade Street, Bran...  CO11 1RH   610194
# ...

# %% [markdown]
# ## Data Cleaning

# %%
df.isnull().sum()
# Out:
# fsa_id             0
# name               0
# address            0
# postcode           0
# easting            0
# northing           0
# latitude           0
# longitude          0
# local_authority    0
# dtype: int64

# %% [markdown]
# **Replacing "\N" values so that we can detect NaN values from df**

# %%
df['latitude'].replace('\\N', np.nan, inplace=True)

# %%
df['longitude'].replace('\\N', np.nan, inplace=True)

# %%
df.head()
# Out:
#    fsa_id                name
# 0      22          Anchor Inn  \
# 1      36  Ark Bar Restaurant
# 2      74           Black Boy
# 3      75         Black Horse
# 4      76          Black Lion
#
#                                              address  postcode  easting
# 0        Upper Street, Stratford St Mary, COLCHESTER   CO7 6LW   604749  \
# 1  Ark Bar And Restaurant, Cattawade Street, Bran...  CO11 1RH   610194
# 2  The Lady Elizabeth, 7 Market Hill, SUDBURY, Su...  CO10 2EA   587334
# 3        Lower Street, Stratford St Mary, COLCHESTER   CO7 6JS   622675
# 4                      Lion Road, Glemsford, SUDBURY  CO10 7RF   622675
#
#    northing   latitude longitude local_authority
# 0    234404  51.970379  0.979340         Babergh
# 1    233329  51.958698  1.057832         Babergh
# 2    241316  52.038595  0.729915         Babergh
# 3  -5527598        NaN       NaN         Babergh
# 4  -5527598        NaN       NaN         Babergh

# %%
df.isnull().sum()
# Out:
# fsa_id               0
# name                 0
# address              0
# postcode             0
# easting              0
# northing             0
# latitude           767
# longitude          767
# local_authority      0
# dtype: int64

# %% [markdown]
# **Drop NaN from df**

# %%
df1 = df.dropna()

# %%
df1.head()
# Out:
#    fsa_id                name
# 0      22          Anchor Inn  \
# 1      36  Ark Bar Restaurant
# 2      74           Black Boy
# 5      97        Brewers Arms
# 6     102        Bristol Arms
#
#                                              address  postcode  easting
# 0        Upper Street, Stratford St Mary, COLCHESTER   CO7 6LW   604749  \
# 1  Ark Bar And Restaurant, Cattawade Street, Bran...  CO11 1RH   610194
# 2  The Lady Elizabeth, 7 Market Hill, SUDBURY, Su...  CO10 2EA   587334
# 5  The Brewers Arms, Bower House Tye, Polstead, C...   CO6 5BZ   598743
# 6                     Bristol Hill, Shotley, IPSWICH   IP9 1PU   624624
#
#    northing   latitude longitude local_authority
# 0    234404  51.970379  0.979340         Babergh
# 1    233329  51.958698  1.057832         Babergh
# 2    241316  52.038595  0.729915         Babergh
# 5    240655  52.028694  0.895650         Babergh
# 6    233550  51.955042  1.267642         Babergh

# %%
df1.isnull().sum()
# Out:
# fsa_id             0
# name               0
# address            0
# postcode           0
# easting            0
# northing           0
# latitude           0
# longitude          0
# local_authority    0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Checking df1 for correct Dtypes**

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50564 entries, 0 to 51330
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   fsa_id           50564 non-null  int64
#  1   name             50564 non-null  object
#  2   address          50564 non-null  object
#  3   postcode         50564 non-null  object
#  4   easting          50564 non-null  int64
#  5   northing         50564 non-null  int64
#  6   latitude         50564 non-null  object
#  7   longitude        50564 non-null  object
#  8   local_authority  50564 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 3.9+ MB

# %%
df1['latitude'] = df1['latitude'].astype(float)
# Out:
# C:\Users\abc\AppData\Local\Temp\ipykernel_16568\3953391777.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['latitude'] = df1['latitude'].astype(float)

# %%
df1['longitude'] = df1['longitude'].astype(float)
# Out:
# C:\Users\abc\AppData\Local\Temp\ipykernel_16568\1229561129.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['longitude'] = df1['longitude'].astype(float)

# %%
df1.head()
# Out:
#    fsa_id                name
# 0      22          Anchor Inn  \
# 1      36  Ark Bar Restaurant
# 2      74           Black Boy
# 5      97        Brewers Arms
# 6     102        Bristol Arms
#
#                                              address  postcode  easting
# 0        Upper Street, Stratford St Mary, COLCHESTER   CO7 6LW   604749  \
# 1  Ark Bar And Restaurant, Cattawade Street, Bran...  CO11 1RH   610194
# 2  The Lady Elizabeth, 7 Market Hill, SUDBURY, Su...  CO10 2EA   587334
# 5  The Brewers Arms, Bower House Tye, Polstead, C...   CO6 5BZ   598743
# 6                     Bristol Hill, Shotley, IPSWICH   IP9 1PU   624624
#
#    northing   latitude  longitude local_authority
# 0    234404  51.970379   0.979340         Babergh
# 1    233329  51.958698   1.057832         Babergh
# 2    241316  52.038595   0.729915         Babergh
# 5    240655  52.028694   0.895650         Babergh
# 6    233550  51.955042   1.267642         Babergh

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50564 entries, 0 to 51330
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   fsa_id           50564 non-null  int64
#  1   name             50564 non-null  object
#  2   address          50564 non-null  object
#  3   postcode         50564 non-null  object
#  4   easting          50564 non-null  int64
#  5   northing         50564 non-null  int64
#  6   latitude         50564 non-null  float64
#  7   longitude        50564 non-null  float64
#  8   local_authority  50564 non-null  object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 3.9+ MB

# %%
points=np.array((float(input()),float(input())))
points #51.970388
#1.057536
# Out:
# 51.97
# 1.07
# array([51.97,  1.07])

# %% [markdown]
# ## Converting Longitude and Lattitude into Cordinate

# %%
arr=np.array([df1['latitude'],df1['longitude']]).T
arr
# Out:
# array([[51.970379,  0.97934 ],
#        [51.958698,  1.057832],
#        [52.038595,  0.729915],
#        ...,
#        [53.044998, -2.996966],
#        [53.053094, -2.959124],
#        [53.076638, -3.050512]])

# %%
distance=np.sum((arr-points)**2, axis=1)
distance
# Out:
# array([8.21937924e-03, 2.75795428e-04, 1.20363081e-01, ...,
#        1.76958331e+01, 1.74069328e+01, 1.82032668e+01])

# %%
df1['Distance']=distance
# Out:
# C:\Users\abc\AppData\Local\Temp\ipykernel_16568\832327565.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Distance']=distance

# %%
df1
# Out:
#        fsa_id                                      name
# 0          22                                Anchor Inn  \
# 1          36                        Ark Bar Restaurant
# 2          74                                 Black Boy
# 5          97                              Brewers Arms
# 6         102                              Bristol Arms
# ...       ...                                       ...
# 51326  597119  Wrexham & District War Memorial Club Ltd
# 51327  597127                 Wrexham Lager Social Club
# 51328  597130         Wrexham Rail Sports & Social Club
# 51329  597131                        Wrexham Rugby Club
# 51330  597137                                     Y Tai
#
#                                                  address  postcode  easting
# 0            Upper Street, Stratford St Mary, COLCHESTER   CO7 6LW   604749  \
# 1      Ark Bar And Restaurant, Cattawade Street, Bran...  CO11 1RH   610194
# ...

# %%
df1.sort_values(by='Distance', ascending=True)[:5]
# Out:
#     fsa_id                name
# 29     591           Royal Oak  \
# 1       36  Ark Bar Restaurant
# 60     797          The Grange
# 52     775       The Crown Inn
# 42     757            The Bull
#
#                                               address  postcode  easting
# 29  Royal Oak, East End Lane, East Bergholt, COLCH...   CO7 6XA   609998  \
# 1   Ark Bar And Restaurant, Cattawade Street, Bran...  CO11 1RH   610194
# 60  The Grange Country Park, Straight Road, East B...   CO7 6UX   609841
# 52  Crown Inn, Cattawade Street, Brantham, MANNING...  CO11 1RE   610209
# 42    The Bull Inn, The Street, Brantham, MANNINGTREE  CO11 1PN   612239
#
#     northing   latitude  longitude local_authority  Distance
# 29    235171  51.975311   1.056110         Babergh  0.000221
# 1     233329  51.958698   1.057832         Babergh  0.000276
# 60    235186  51.975506   1.053837         Babergh  0.000292
# 52    233104  51.956673   1.057912         Babergh  0.000324
# ...

# %% [markdown]
# **These are top 5 nearest pubs location around the given cordinate**

# %%
df1.to_csv('data_cleaned_pub.csv',index=False)
